# %% [markdown]
# ## Predicting Breast Cancer using LogisticRegression, DecisionTree, RandomForest, SpaceVectorMachine and KNearestNeighbor Classifiers

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report,accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split, KFold,GridSearchCV
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Reading the dataset

# %%
#Reading dataset
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/data.csv')
df.head(5)
# Out:
#          id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0    842302         M  ...                  0.11890          NaN
# 1    842517         M  ...                  0.08902          NaN
# 2  84300903         M  ...                  0.08758          NaN
# 3  84348301         M  ...                  0.17300          NaN
# 4  84358402         M  ...                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
print(df.shape)
print(len(df))
print(len(df.columns))
# Out:
# (569, 33)
# 569
# 33

# %% [markdown]
# ## Columns/Variables in the dataset

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %% [markdown]
# The above dataset has 33 columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
#  32  Unnamed: 32              0 non-null      float64
# dtypes: float64(31), int64(1), object(1)
# memory usage: 146.8+ KB

# %% [markdown]
# The column 32(Unnamed:32) has all NULL values and can be removed

# %%
df.rename({"Unnamed: 32":"a"}, axis="columns", inplace=True)
df.drop(["a"], axis=1, inplace=True)
df.head(3)
# Out:
#          id diagnosis  ...  symmetry_worst  fractal_dimension_worst
# 0    842302         M  ...          0.4601                  0.11890
# 1    842517         M  ...          0.2750                  0.08902
# 2  84300903         M  ...          0.3613                  0.08758
#
# [3 rows x 32 columns]

# %% [markdown]
# Target variable diagnosis is a categorial variable M: Malignant, B: Benign. It is changed to M:1, B:0

# %%
df['diagnosis'] = df['diagnosis'].apply(lambda x : '1' if x == 'M' else '0')
df = df.set_index('id')
df.head(3)
# Out:
#          diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# id                               ...
# 842302           1        17.99  ...          0.4601                  0.11890
# 842517           1        20.57  ...          0.2750                  0.08902
# 84300903         1        19.69  ...          0.3613                  0.08758
#
# [3 rows x 31 columns]

# %% [markdown]
# After removing Unnamed:32 column and makind id column as an index label the dataset has 31 columns/variables(including target variable)

# %%
print(len(df.columns))
# Out:
# 31

# %% [markdown]
# ## Number of benign and malignant observations

# %%
# Number of Benign and Malignant observations
benign,malignant = df['diagnosis'].value_counts()
print("Number of Benign patients", benign)
print("Number of Malignant patients", malignant)

plt.figure(figsize = (8,4))
sns.countplot(df['diagnosis'])
# Out:
# Number of Benign patients 357
# Number of Malignant patients 212
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Target and Feature variables

# %%
y = df['diagnosis'].values # Target variable
X = df.drop('diagnosis', axis =1).values # Feature variables

# %% [markdown]
# ## Spliting data into train and test sets

# %%
#splitting dataset
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2, random_state = 20)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (455, 30)
# (114, 30)
# (455,)
# (114,)

# %% [markdown]
# ## Data Normalization

# %%
# Normalization
sc = StandardScaler()
X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.fit_transform(X_test)

# %% [markdown]
# ## Logistic Regression

# %%
# Building model
model = LogisticRegression()
model.fit(X_train_sc,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
#Predicting and estimating accuracy on training and test datasets
y_pred_lr = model.predict(X_test_sc)
accuracy_lr_train = model.score(X_train_sc,y_train)
print("Accuracy on Training Data:",accuracy_lr_train)
accuracy_lr = accuracy_score(y_test,y_pred_lr)
print("Accuracy on Test Data:",accuracy_lr)
# Out:
# Accuracy on Training Data: 0.9868131868131869
# Accuracy on Test Data: 0.9824561403508771

# %% [markdown]
# Logistic Regression with GridCVSearch and KFold Crossvalidation

# %%
#Model building
model = LogisticRegression(max_iter=1000)

#Tuning parameters
parameters = {'C':[0.001,0.01, 0.1, 0.2,0.3, 1,10,100,200]}
grid_search = GridSearchCV(model, parameters, cv = 10) # 10 Fold Cross Validation

# Model fitting
grid_search.fit(X_train_sc, y_train)


print("Best Score is ", grid_search.best_score_)
print("Best Estimator is ", grid_search.best_estimator_)
print("Best Parametes are", grid_search.best_params_)
# Out:
# Best Score is  0.9758454106280194
# Best Estimator is  LogisticRegression(C=0.3, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
# Best Parametes are {'C': 0.3}

# %%
#After hyperparameter tuning
model = LogisticRegression(C = 0.3)
model.fit(X_train_sc, y_train)
y_pred_lr = model.predict(X_test_sc)
accuracy_lr = accuracy_score(y_test,y_pred_lr)
print("Accuracy on Test Data:",accuracy_lr)
# Out:
# Accuracy on Test Data: 0.9824561403508771

# %% [markdown]
# Classification report

# %%
print(classification_report(y_test, y_pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99        66
#            1       1.00      0.96      0.98        48
#
#     accuracy                           0.98       114
#    macro avg       0.99      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114

# %% [markdown]
# Confusion matrix

# %%
confusion_matrix(y_test,y_pred_lr)
lr_cm = confusion_matrix(y_test, y_pred_lr)
lr_cm = pd.DataFrame(lr_cm, columns=['Benign', 'Malignant'], index=['Benign','Malignant'])
lr_cm
# Out:
#            Benign  Malignant
# Benign         66          0
# Malignant       2         46

# %% [markdown]
# ## DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()
model.fit(X_train_sc,y_train)
y_pred_dt = model.predict(X_test_sc)

# %%
accuracy_dt_train = model.score(X_train_sc,y_train)
print("Accuracy on Training Data:",accuracy_dt_train)
accuracy_dt = accuracy_score(y_test,y_pred_dt)
print("Accuracy on Test Data:",accuracy_dt)
# Out:
# Accuracy on Training Data: 1.0
# Accuracy on Test Data: 0.9473684210526315

# %% [markdown]
# DecisionTreeClassifier with GridCVSearch and KFold Crossvalidation

# %%
#model building
model = DecisionTreeClassifier()

# Tunning Paramaters
parameters = {'min_samples_split': [2,3,4,5,6,7,8,9,10], 
              'min_samples_leaf':[2,3,4,5,6,7,8,9,10],
              'max_features': ['auto', 'sqrt', 'log2']}


# GridSearchCV
grid_search = GridSearchCV(model, parameters, cv=10) # For 10 Cross-Validation

grid_search.fit(X_train_sc, y_train) # Model Fitting
print("Best Score is ", grid_search.best_score_)
print("Best Estinator is ", grid_search.best_estimator_)
print("Best Parametes are", grid_search.best_params_)
# Out:
# Best Score is  0.9472946859903383
# Best Estinator is  DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=3, min_samples_split=4,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')
# Best Parametes are {'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 4}

# %%
#After hyperparameter tuning
model = DecisionTreeClassifier(max_features = 'sqrt', min_samples_leaf=4, min_samples_split=9)
model.fit(X_train_sc, y_train)
y_pred_dt = model.predict(X_test_sc)
accuracy_dt = accuracy_score(y_test,y_pred_dt)
print("Accuracy on Test Data:",accuracy_dt)
# Out:
# Accuracy on Test Data: 0.9035087719298246

# %% [markdown]
# Classification report

# %%
print(classification_report(y_test, y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92        66
#            1       0.93      0.83      0.88        48
#
#     accuracy                           0.90       114
#    macro avg       0.91      0.89      0.90       114
# weighted avg       0.91      0.90      0.90       114

# %% [markdown]
# Confusion matrix

# %%
confusion_matrix(y_test,y_pred_dt)
lr_cm = confusion_matrix(y_test, y_pred_dt)
lr_cm = pd.DataFrame(lr_cm, columns=['Benign', 'Malignant'], index=['Benign','Malignant'])
lr_cm
# Out:
#            Benign  Malignant
# Benign         63          3
# Malignant       8         40

# %% [markdown]
# ## RandomForestClassifier

# %%
model = RandomForestClassifier()
model.fit(X_train_sc,y_train)
y_pred_rf = model.predict(X_test_sc)

# %%
accuracy_rf_train = model.score(X_train_sc,y_train)
print("Accuracy on Training Data:",accuracy_rf_train)
accuracy_rf = accuracy_score(y_test,y_pred_rf)
print("Accuracy on Test Data:",accuracy_rf)
# Out:
# Accuracy on Training Data: 1.0
# Accuracy on Test Data: 0.9736842105263158

# %% [markdown]
# RandomForestClassifier with GridCVSearch and KFold Crossvalidation

# %%
#model building
model = RandomForestClassifier()

# Tunning Paramaters
parameters = {'n_estimators': [100,150,200,250,300],
              'max_depth': [5,10,20, None], 
              'max_features': ['auto', 'sqrt'],
              'min_samples_leaf': [1, 2, 3],
              'min_samples_split': [2, 5, 10],
              'bootstrap': [True, False],
              } 
# GridSearchCV
grid_search = GridSearchCV(model, parameters, cv=10) 

grid_search.fit(X_train_sc, y_train) 

print("Best Score is ", grid_search.best_score_)
print("Best Estinator is ", grid_search.best_estimator_)
print("Best Parametes are", grid_search.best_params_)
# Out:
# Best Score is  0.9691787439613527
# Best Estinator is  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# Best Parametes are {'bootstrap': True, 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}

# %%
#After hyperparameter tuning
model = RandomForestClassifier(bootstrap = True, max_depth = None, max_features = 'auto', min_samples_leaf = 1, min_samples_split = 2, n_estimators = 200)
model.fit(X_train_sc, y_train)
y_pred_rf = model.predict(X_test_sc)
accuracy_rf = accuracy_score(y_test,y_pred_rf)
print("Accuracy on Test Data:",accuracy_rf)
# Out:
# Accuracy on Test Data: 0.9736842105263158

# %% [markdown]
# Classification report

# %%
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        66
#            1       1.00      0.94      0.97        48
#
#     accuracy                           0.97       114
#    macro avg       0.98      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114

# %% [markdown]
# Confusion matrix

# %%
confusion_matrix(y_test,y_pred_rf)
lr_cm = confusion_matrix(y_test, y_pred_rf)
lr_cm = pd.DataFrame(lr_cm, columns=['Benign', 'Malignant'], index=['Benign','Malignant'])
lr_cm
# Out:
#            Benign  Malignant
# Benign         66          0
# Malignant       3         45

# %% [markdown]
# ## SpaceVectorClassifier

# %%
model = SVC()
model.fit(X_train_sc,y_train)
y_pred_svc = model.predict(X_test_sc)

# %%
accuracy_svc_train = model.score(X_train_sc,y_train)
print("Accuracy on Training Data:",accuracy_svc_train)
accuracy_svc = accuracy_score(y_test,y_pred_svc)
print("Accuracy on Test Data:",accuracy_svc)
# Out:
# Accuracy on Training Data: 0.9846153846153847
# Accuracy on Test Data: 0.9736842105263158

# %% [markdown]
# SpaceVectorClassifier with GridCVSearch and KFold Crossvalidation

# %%
#model building
model = SVC()

# Tunning Paramaters
parameters = {'C':[0.1, 0.3, 0.5, 0.7, 0.9, 1.0, 1.3, 1.5, 1.7, 2.0],
              'kernel' :['linear', 'poly', 'rbf', 'sigmoid']} 

# GridSearchCV
grid_search = GridSearchCV(model, parameters, cv=10) 
grid_search.fit(X_train_sc, y_train) 

print("Best Score is ", grid_search.best_score_)
print("Best Estinator is ", grid_search.best_estimator_)
print("Best Parametes are", grid_search.best_params_)
# Out:
# Best Score is  0.9780193236714976
# Best Estinator is  SVC(C=0.1, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
# Best Parametes are {'C': 0.1, 'kernel': 'linear'}

# %%
#After hyperparameter tuning
model = SVC(C = 0.1, kernel = 'linear')
model.fit(X_train_sc, y_train)
y_pred_svc = model.predict(X_test_sc)
accuracy_svc = accuracy_score(y_test,y_pred_svc)
print("Accuracy on Test Data:",accuracy_svc)
# Out:
# Accuracy on Test Data: 0.9736842105263158

# %% [markdown]
# Classification report

# %%
print(classification_report(y_test, y_pred_svc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        66
#            1       1.00      0.94      0.97        48
#
#     accuracy                           0.97       114
#    macro avg       0.98      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114

# %% [markdown]
# Confusion matrix

# %%
confusion_matrix(y_test,y_pred_svc)
lr_cm = confusion_matrix(y_test, y_pred_svc)
lr_cm = pd.DataFrame(lr_cm, columns=['Benign', 'Malignant'], index=['Benign','Malignant'])
lr_cm
# Out:
#            Benign  Malignant
# Benign         66          0
# Malignant       3         45

# %% [markdown]
# ## K-Nearest Neigbors(KNN)

# %%
model = KNeighborsClassifier()
model.fit(X_train_sc,y_train)
y_pred_knn = model.predict(X_test_sc)

# %%
accuracy_knn_train = model.score(X_train_sc,y_train)
print("Accuracy on Training Data:",accuracy_knn_train)
accuracy_knn = accuracy_score(y_test,y_pred_knn)
print("Accuracy on Test Data:",accuracy_knn)
# Out:
# Accuracy on Training Data: 0.9714285714285714
# Accuracy on Test Data: 0.9736842105263158

# %% [markdown]
# K-Nearest Neigbors(KNN) with GridCVSearch and KFold Crossvalidation

# %%
#model building
model = KNeighborsClassifier()

# Tunning Paramaters
parameters = {'n_neighbors': list(range(1, 30)),
              'leaf_size': list(range(1,30)),
              'weights': [ 'distance', 'uniform']} 

# GridSearchCV
grid_search = GridSearchCV(model, parameters, cv=10) 
grid_search.fit(X_train_sc, y_train) 

print("Best Score is ", grid_search.best_score_)
print("Best Estinator is ", grid_search.best_estimator_)
print("Best Parametes are", grid_search.best_params_)
# Out:
# Best Score is  0.9671014492753625
# Best Estinator is  KNeighborsClassifier(algorithm='auto', leaf_size=1, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=6, p=2,
#                      weights='distance')
# Best Parametes are {'leaf_size': 1, 'n_neighbors': 6, 'weights': 'distance'}

# %%
#After hyperparameter tuning
model = KNeighborsClassifier(leaf_size =1, n_neighbors =  6, weights = 'distance')
model.fit(X_train_sc, y_train)
y_pred_knn = model.predict(X_test_sc)
accuracy_knn = accuracy_score(y_test,y_pred_knn)
print("Accuracy on Test Data:",accuracy_knn)
# Out:
# Accuracy on Test Data: 0.9649122807017544

# %% [markdown]
# Classification report

# %%
print(classification_report(y_test, y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97        66
#            1       0.98      0.94      0.96        48
#
#     accuracy                           0.96       114
#    macro avg       0.97      0.96      0.96       114
# weighted avg       0.97      0.96      0.96       114

# %% [markdown]
# Confusion matrix

# %%
confusion_matrix(y_test,y_pred_knn)
lr_cm = confusion_matrix(y_test, y_pred_knn)
lr_cm = pd.DataFrame(lr_cm, columns=['Benign', 'Malignant'], index=['Benign','Malignant'])
lr_cm
# Out:
#            Benign  Malignant
# Benign         65          1
# Malignant       3         45

# %% [markdown]
# The accuracies obtained by the above algorithms are as follows:
#
# 1. Logistic Regression — 98.24%
#
# 2. Decision Tree Algorithm — 90.35%
#
# 3. Random Forest Classification — 97.36%
#
# 4. Support Vector Machines — 97.36%
#
# 5. K - Nearest Neighbor — 96.49%
